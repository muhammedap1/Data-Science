# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('sales.csv')

# %%
data.head()
# Out:
#     Brands        Models         Colors Memory Storage Camera  Rating  \
# 0  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes     4.3
# 1    Nokia           3.2          Steel   2 GB   16 GB    Yes     3.8
# 2   realme           C2   Diamond Black   2 GB     NaN    Yes     4.4
# 3  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes     4.2
# 4    Apple    iPhone 11           Black    4GB   64 GB    Yes     4.6
#
#    Selling Price  Original Price                Mobile  Discount  \
# 0          19330           20999  SAMSUNG GALAXY M31S       1669
# 1          10199           10199             Nokia 3.2         0
# 2           6999            7999            realme C2       1000
# 3          12999           12999        Infinix Note 5         0
# 4          49900           49900      Apple iPhone 11          0
#
#    discount percentage
# 0             7.947998
# 1             0.000000
# 2            12.501563
# 3             0.000000
# 4             0.000000

# %%
data['Storage']=data['Storage'].str.extract('(\d+)')

# %%
data.head()
# Out:
#     Brands        Models         Colors Memory Storage Camera  Rating  \
# 0  SAMSUNG  GALAXY M31S    Mirage Black      8     128    Yes     4.3
# 1    Nokia           3.2          Steel      2      16    Yes     3.8
# 2   realme           C2   Diamond Black      2     NaN    Yes     4.4
# 3  Infinix        Note 5       Ice Blue      4      64    Yes     4.2
# 4    Apple    iPhone 11           Black      4      64    Yes     4.6
#
#    Selling Price  Original Price                Mobile  Discount  \
# 0          19330           20999  SAMSUNG GALAXY M31S       1669
# 1          10199           10199             Nokia 3.2         0
# 2           6999            7999            realme C2       1000
# 3          12999           12999        Infinix Note 5         0
# 4          49900           49900      Apple iPhone 11          0
#
#    discount percentage
# 0             7.947998
# 1             0.000000
# 2            12.501563
# 3             0.000000
# 4             0.000000

# %%
data=data.drop(columns=['Camera'])

# %%
data.head()
# Out:
#     Brands        Models         Colors Memory Storage  Rating  Selling Price  \
# 0  SAMSUNG  GALAXY M31S    Mirage Black      8     128     4.3          19330
# 1    Nokia           3.2          Steel      2      16     3.8          10199
# 2   realme           C2   Diamond Black      2     NaN     4.4           6999
# 3  Infinix        Note 5       Ice Blue      4      64     4.2          12999
# 4    Apple    iPhone 11           Black      4      64     4.6          49900
#
#    Original Price                Mobile  Discount  discount percentage
# 0           20999  SAMSUNG GALAXY M31S       1669             7.947998
# 1           10199             Nokia 3.2         0             0.000000
# 2            7999            realme C2       1000            12.501563
# 3           12999        Infinix Note 5         0             0.000000
# 4           49900      Apple iPhone 11          0             0.000000

# %%
data.head(5)
# Out:
#     Brands        Models         Colors Memory Storage  Rating  Selling Price  \
# 0  SAMSUNG  GALAXY M31S    Mirage Black      8     128     4.3          19330
# 1    Nokia           3.2          Steel      2      16     3.8          10199
# 2   realme           C2   Diamond Black      2     NaN     4.4           6999
# 3  Infinix        Note 5       Ice Blue      4      64     4.2          12999
# 4    Apple    iPhone 11           Black      4      64     4.6          49900
#
#    Original Price                Mobile  Discount  discount percentage
# 0           20999  SAMSUNG GALAXY M31S       1669             7.947998
# 1           10199             Nokia 3.2         0             0.000000
# 2            7999            realme C2       1000            12.501563
# 3           12999        Infinix Note 5         0             0.000000
# 4           49900      Apple iPhone 11          0             0.000000
