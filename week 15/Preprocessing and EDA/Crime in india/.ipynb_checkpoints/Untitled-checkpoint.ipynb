# %%
#importing librarys
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
df=pd.read_csv('IndianCrime.csv')

# %%
pd.set_option('display.max_columns',None)

# %%
df.head(4)
# Out:
#          STATE/UT   DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  ANDHRA PRADESH   ADILABAD  2001     101                 60
# 1  ANDHRA PRADESH  ANANTAPUR  2001     151                125
# 2  ANDHRA PRADESH   CHITTOOR  2001     101                 57
# 3  ANDHRA PRADESH   CUDDAPAH  2001      80                 53
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
# 2                                          2    27               0
# 3                                          1    20               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  \
# 0          50                      46
# 1          23                      53
# 2          27                      59
# 3          20                      25
#
#    KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS  \
# 0                                           30
# ...

# %%
df.shape
# Out:
# (9840, 33)

# %%
df.describe()
# Out:
#               YEAR       MURDER  ATTEMPT TO MURDER  \
# count  9840.000000  9840.000000        9840.000000
# mean   2007.161890    88.565854          78.738618
# std       3.755581   325.417692         306.650391
# min    2001.000000     0.000000           0.000000
# 25%    2004.000000    18.000000          10.000000
# 50%    2007.000000    37.000000          28.000000
# 75%    2010.000000    66.000000          57.000000
# max    2013.000000  7601.000000        7964.000000
#
#        CULPABLE HOMICIDE NOT AMOUNTING TO MURDER         RAPE  CUSTODIAL RAPE  \
# count                                9840.000000  9840.000000     9840.000000
# mean                                    9.754878    55.456098        0.005488
# std                                    58.733349   201.690457        0.111218
# min                                     0.000000     0.000000        0.000000
# 25%                                     0.000000     8.000000        0.000000
# ...

# %%
corr=df.corr(numeric_only=True)

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
df['STATE/UT'].unique()
# Out:
# array(['ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR',
#        'CHHATTISGARH', 'GOA', 'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH',
#        'JAMMU & KASHMIR', 'JHARKHAND', 'KARNATAKA', 'KERALA',
#        'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA', 'MIZORAM',
#        'NAGALAND', 'ODISHA', 'PUNJAB', 'RAJASTHAN', 'SIKKIM',
#        'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH', 'UTTARAKHAND',
#        'WEST BENGAL', 'A & N ISLANDS', 'CHANDIGARH', 'D & N HAVELI',
#        'DAMAN & DIU', 'DELHI UT', 'LAKSHADWEEP', 'PUDUCHERRY',
#        'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
# ...

# %%
values=df['STATE/UT'].value_counts().head(10)

# %%
values.plot(kind='bar')
# Out:
# <Axes: xlabel='STATE/UT'>

# %%
value=df['YEAR'].value_counts()

# %%
value.plot(kind='line',marker='o',color='green')
# Out:
# <Axes: xlabel='YEAR'>

# %%
df.groupby(['MURDER','YEAR']).size()
# Out:
# MURDER  YEAR
# 0       2001     9
#         2002    13
#         2003    15
#         2004     9
#         2005    11
#                 ..
# 5480    2006     1
# 5711    2005     1
# 6126    2004     1
# 6825    2002     1
# 7601    2001     1
# Length: 2184, dtype: int64

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1  ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2  ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3  ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4  ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
# 2                                          2    27               0
# 3                                          1    20               0
# 4                                          1    23               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  \
# 0          50                      46
# 1          23                      53
# 2          27                      59
# ...

# %%
a=df.groupby(['DISTRICT'])['MURDER'].sum().sort_values(ascending=False).head(10)

# %%
a.plot(kind='bar',color='skyblue')
plt.title('Murder By State')
plt.show()

# %%
a=df.groupby(['STATE/UT'])['TOTAL IPC CRIMES'].sum().sort_values(ascending=False).head(10)

# %%
a.plot(kind='bar')
# Out:
# <Axes: xlabel='STATE/UT'>

# %%
df.groupby([''])
