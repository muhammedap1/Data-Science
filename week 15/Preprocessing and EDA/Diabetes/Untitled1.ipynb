# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('diabetes.csv')

# %%
pd.set_option('display.max_columns',None)

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Actual  Predicted
# 0                     0.627   50       1          1
# 1                     0.351   31       0          0
# 2                     0.672   32       1          2
# 3                     0.167   21       0          1
# 4                     2.288   33       1          1
# 5                     0.201   30       0          2
# 6                     0.248   26       2          0
# 7                     0.134   29       0          0
# 8                     0.158   53       1          0
# 9                     0.232   54       1          1

# %%
corr=df.corr()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
df.groupby(['Glucose','Actual']).size()
# Out:
# Glucose  Actual
# 0        1         2
#          2         3
# 44       0         1
# 56       0         1
# 57       0         1
#                   ..
# 196      1         3
# 197      1         3
#          2         1
# 198      1         1
# 199      1         1
# Length: 272, dtype: int64

# %%
sns.lineplot(x='Glucose',y='Actual',data=df)
# Out:
# <Axes: xlabel='Glucose', ylabel='Actual'>

# %%
sns.
