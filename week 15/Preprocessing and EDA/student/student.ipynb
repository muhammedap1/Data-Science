# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
data=pd.read_csv('student-scores.csv')

# %%
data.head(10)
# Out:
#    id first_name  last_name                                  email  gender  \
# 0   1       Paul      Casey         paul.casey.1@gslingacademy.com    male
# 1   2   Danielle   Sandoval  danielle.sandoval.2@gslingacademy.com  female
# 2   3       Tina    Andrews       tina.andrews.3@gslingacademy.com  female
# 3   4       Tara      Clark         tara.clark.4@gslingacademy.com  female
# 4   5    Anthony     Campos     anthony.campos.5@gslingacademy.com    male
# 5   6      Kelly       Wade         kelly.wade.6@gslingacademy.com  female
# 6   7    Anthony      Smith      anthony.smith.7@gslingacademy.com    male
# 7   8     George      Short       george.short.8@gslingacademy.com    male
# 8   9    Stanley  Gutierrez  stanley.gutierrez.9@gslingacademy.com    male
# 9  10     Audrey    Simpson    audrey.simpson.10@gslingacademy.com  female
#
#    part_time_job  absence_days  extracurricular_activities  \
# 0          False             3                       False
# ...

# %%
data['absence_days'].value_counts()
# Out:
# absence_days
# 2     344
# 1     341
# 3     336
# 4     199
# 5     196
# 6     136
# 7     130
# 0     123
# 10     88
# 9      56
# 8      51
# Name: count, dtype: int64

# %%
job_name=data['part_time_job'].value_counts().index

# %%
job_val=data['part_time_job'].value_counts().values

# %%
plt.pie(job_val,labels=job_name,autopct='%1.01f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1b648014ce0>,
# ...
#  [Text(-0.9672479537657722, 0.5238620008512994, 'False'),
#   Text(0.9672479782895212, -0.5238619555711543, 'True')],
#  [Text(-0.5275897929631485, 0.28574290955525417, '84.2%'),
#   Text(0.5275898063397388, -0.28574288485699323, '15.8%')])

# %%
ex_name=data['extracurricular_activities'].value_counts().index
ex_val=data['extracurricular_activities'].value_counts().values

# %%
plt.pie(ex_val,labels=ex_name,autopct='%1.01f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1b64776c920>,
# ...
#  [Text(-0.8817236912399349, 0.6576954707964957, 'False'),
#   Text(0.8817236912399347, -0.6576954707964959, 'True')],
#  [Text(-0.48094019522178255, 0.35874298407081584, '79.6%'),
#   Text(0.4809401952217825, -0.3587429840708159, '20.4%')])

# %%
data.head(10)
# Out:
#    id first_name  last_name                                  email  gender  \
# 0   1       Paul      Casey         paul.casey.1@gslingacademy.com    male
# 1   2   Danielle   Sandoval  danielle.sandoval.2@gslingacademy.com  female
# 2   3       Tina    Andrews       tina.andrews.3@gslingacademy.com  female
# 3   4       Tara      Clark         tara.clark.4@gslingacademy.com  female
# 4   5    Anthony     Campos     anthony.campos.5@gslingacademy.com    male
# 5   6      Kelly       Wade         kelly.wade.6@gslingacademy.com  female
# 6   7    Anthony      Smith      anthony.smith.7@gslingacademy.com    male
# 7   8     George      Short       george.short.8@gslingacademy.com    male
# 8   9    Stanley  Gutierrez  stanley.gutierrez.9@gslingacademy.com    male
# 9  10     Audrey    Simpson    audrey.simpson.10@gslingacademy.com  female
#
#    part_time_job  absence_days  extracurricular_activities  \
# 0          False             3                       False
# ...

# %%
data['career_aspiration'].value_counts().head(10)
# Out:
# career_aspiration
# Software Engineer        315
# Business Owner           309
# Unknown                  223
# Banker                   169
# Lawyer                   138
# Accountant               126
# Doctor                   119
# Real Estate Developer     83
# Stock Investor            73
# Construction Engineer     68
# Name: count, dtype: int64

# %%
data['absence_days'].unique()
# Out:
# array([ 3,  2,  9,  5,  6,  1,  7, 10,  8,  4,  0], dtype=int64)

# %%
data.loc[index,:]
# Out:
#       id first_name last_name                                  email  gender  \
# 344  345    Melissa        Le       melissa.le.345@gslingacademy.com  female
# 341  342     Donald    Carson    donald.carson.342@gslingacademy.com    male
# 336  337      Scott    Hughes     scott.hughes.337@gslingacademy.com    male
# 199  200    Kathryn   Frazier  kathryn.frazier.200@gslingacademy.com  female
# 196  197       Mark     Myers       mark.myers.197@gslingacademy.com    male
# 136  137      David     Patel      david.patel.137@gslingacademy.com    male
# 130  131     Amanda   Vasquez   amanda.vasquez.131@gslingacademy.com  female
# 123  124      Wendy     Lewis      wendy.lewis.124@gslingacademy.com  female
# 88    89     Robert    Atkins     robert.atkins.89@gslingacademy.com    male
# 56    57    Melissa       Lee       melissa.lee.57@gslingacademy.com  female
# 51    52     Sandra  Thornton   sandra.thornton.52@gslingacademy.com  female
#
# ...

# %%
data['Total Score']=data['math_score']+data['history_score']+data['physics_score']+data['chemistry_score']+data['biology_score']+data['english_score']+data['geography_score']

# %%
data.head(10)
# Out:
#    id first_name  last_name                                  email  gender  \
# 0   1       Paul      Casey         paul.casey.1@gslingacademy.com    male
# 1   2   Danielle   Sandoval  danielle.sandoval.2@gslingacademy.com  female
# 2   3       Tina    Andrews       tina.andrews.3@gslingacademy.com  female
# 3   4       Tara      Clark         tara.clark.4@gslingacademy.com  female
# 4   5    Anthony     Campos     anthony.campos.5@gslingacademy.com    male
# 5   6      Kelly       Wade         kelly.wade.6@gslingacademy.com  female
# 6   7    Anthony      Smith      anthony.smith.7@gslingacademy.com    male
# 7   8     George      Short       george.short.8@gslingacademy.com    male
# 8   9    Stanley  Gutierrez  stanley.gutierrez.9@gslingacademy.com    male
# 9  10     Audrey    Simpson    audrey.simpson.10@gslingacademy.com  female
#
#    part_time_job  absence_days  extracurricular_activities  \
# 0          False             3                       False
# ...
